# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace2026-cmd/100-days-of-code-/blob/main/Day1_first_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(f"My name is Grace")
print(f"I'm learing Data/AI")
print(f"In 6 months I'll be earning in dollars ")
print(f"By month 6 I'll be a senior")
# Out:
# My name is Grace
# I'm learing Data/AI
# In 6 months I'll be earning in dollars
# By month 6 I'll be a senior
