# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace2026-cmd/100-days-of-code-/blob/main/Day2_second_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(f"Even with cramps at 10%,my motivation is on 100% ")
# Out:
# Even with cramps at 10%,my motivation is on 100%
